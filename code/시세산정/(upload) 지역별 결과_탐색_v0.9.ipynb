# %%
import pandas as pd
import numpy as np

# import timedelta
# 오늘날짜 기준
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'

dt = datetime.datetime.now()
fl_dt = float(str(dt.year) + "." + str(dt.month))

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '송파구')]

# %%
price_time_01_1['강남역_소요시간']
# Out:
# 35.0

# %%
def time_div(x):
    if x <= price_time_01_1['강남역_소요시간'].quantile(q=0.1):
        return price_time_01_1['강남역_소요시간'].quantile(q=0.1)
    elif x > price_time_01_1['강남역_소요시간'].quantile(q=0.1) and x <= price_time_01_1['강남역_소요시간'].quantile(q=0.2):
        return price_time_01_1['강남역_소요시간'].quantile(q=0.2)
    elif x > price_time_01_1['강남역_소요시간'].quantile(q=0.2) and x <= price_time_01_1['강남역_소요시간'].quantile(q=0.3):
        return price_time_01_1['강남역_소요시간'].quantile(q=0.3)
    elif x > price_time_01_1['강남역_소요시간'].quantile(q=0.3) and x <= price_time_01_1['강남역_소요시간'].quantile(q=0.4):
        return price_time_01_1['강남역_소요시간'].quantile(q=0.4)
    elif x > price_time_01_1['강남역_소요시간'].quantile(q=0.4) and x <= price_time_01_1['강남역_소요시간'].quantile(q=0.5):
        return price_time_01_1['강남역_소요시간'].quantile(q=0.5)
    elif x > price_time_01_1['강남역_소요시간'].quantile(q=0.5) and x <= price_time_01_1['강남역_소요시간'].quantile(q=0.6):
        return price_time_01_1['강남역_소요시간'].quantile(q=0.6)
    elif x > price_time_01_1['강남역_소요시간'].quantile(q=0.6) and x <= price_time_01_1['강남역_소요시간'].quantile(q=0.7):
        return price_time_01_1['강남역_소요시간'].quantile(q=0.7)
    elif x > price_time_01_1['강남역_소요시간'].quantile(q=0.7) and x <= price_time_01_1['강남역_소요시간'].quantile(q=0.8):
        return price_time_01_1['강남역_소요시간'].quantile(q=0.8)
    elif x > price_time_01_1['강남역_소요시간'].quantile(q=0.8) and x <= price_time_01_1['강남역_소요시간'].quantile(q=0.9):
        return price_time_01_1['강남역_소요시간'].quantile(q=0.9)
    elif x > price_time_01_1['강남역_소요시간'].quantile(q=0.9) and x <= price_time_01_1['강남역_소요시간'].quantile(q=1):
        return price_time_01_1['강남역_소요시간'].quantile(q=1)
    
    else :
        return -1

# %%
# def pct_div(x):
#     if x < 20:
#         return "~20%"
#     elif x>=20 and x<40:
#         return "20%~40%"
#     elif x>=40 and x<60:
#         return "40%~60%"
#     elif x>=60 and x<80:
#         return "60%~80%"
#     elif x>=80 :
#         return "80%~"
#     else :
#         return -1
def pct_div(x):
    if x < 20:
        return price_time_01_1[price_time_01_1['rank']<20]["강남역_소요시간"].max()
    elif x>=20 and x<40:
        return price_time_01_1[price_time_01_1['rank']<40]["강남역_소요시간"].max()
    elif x>=40 and x<60:
        return price_time_01_1[price_time_01_1['rank']<60]["강남역_소요시간"].max()
    elif x>=60 and x<80:
        return price_time_01_1[price_time_01_1['rank']<80]["강남역_소요시간"].max()
    elif x>=80 :
        return price_time_01_1[price_time_01_1['rank']<=100]["강남역_소요시간"].max()
    else :
        return -1

# %%
price_time_01_1[price_time_01_1['rank']<20]["강남역_소요시간"].max()
# Out:
# 36

# %%
price_time_01_1[price_time_01_1['rank']<40]["강남역_소요시간"].max()
# Out:
# 40

# %%
price_time_01_1[price_time_01_1['rank']<60]["강남역_소요시간"].max()
# Out:
# 43

# %%
np.percentile(price_time_01_1['강남역_소요시간'], 25)
# Out:
# 35.0

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '송파구')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# price_time_01_1['time_div'] = price_time_01_1.apply(lambda x: time_div(x['강남역_소요시간']), axis = 1)
price_time_01_1
# ax = price_time_01_1.plot(x='price_per_size', y = 'time_div', kind = 'scatter', label = 'age_div')
# ax.xaxis.label.set_color('white')
# ax.yaxis.label.set_color('white')
# ax.tick_params(axis = 'y',color='white')

# time_mean = [price_time_01_1['강남역_소요시간'].mean()] * (len(price_time_01))
# ax.plot(time_mean, color = 'red')
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/3551392191.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
#       province_name city_name district_name       view_name   age  net_area  \
# 8646          서울특별시       송파구           잠실동              현대  33.0     71.90
# 8647          서울특별시       송파구           잠실동              현대  33.0     84.68
# 8648          서울특별시       송파구           잠실동           우성 4차  40.0     81.14
# 8649          서울특별시       송파구           잠실동           우성 4차  40.0     95.84
# 8650          서울특별시       송파구           잠실동           우성 4차  40.0    115.83
# 8651          서울특별시       송파구           잠실동          레이크팰리스  17.0     84.82
# ...

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '송파구')]
ax = price_time_01_1.plot(x='price_per_size', y = 'time_div', kind = 'scatter', label = 'age_div')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis = 'y',color='white')

time_mean = [price_time_01_1['강남역_소요시간'].mean()] * (len(price_time_01))
# ax.plot(time_mean, color = 'red')
# Out:
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '송파구')]
ax = price_time_01_1.plot(x='price_per_size', y = 'time_div', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '송파구')]
ax = price_time_01_1.plot(x='rent_per_size', y = 'time_div', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
price_time_01_1 = price_time_01[(price_time_01['age'] >= 10)]
ax = price_time_01_1.plot(x='kb_price', y = 'time_div', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
price_time02 = price_time_01[(price_time_01['gross_area_sub'] == '소형(공급20평대)') & (price_time_01['district_name'] == '가락동')]
price_time02
# Out:
#      province_name city_name district_name      view_name  net_area  \
# 8818         서울특별시       송파구           가락동             극동     59.40
# 8822         서울특별시       송파구           가락동       가락 현대 7차     84.65
# 8823         서울특별시       송파구           가락동           가락금호     59.91
# 8825         서울특별시       송파구           가락동           가락금호     59.91
# 8826         서울특별시       송파구           가락동           가락금호     59.66
# 8827         서울특별시       송파구           가락동       가락 쌍용 1차     59.92
# 8830         서울특별시       송파구           가락동       가락 우성 1차     58.46
# 8835         서울특별시       송파구           가락동          가락 삼환     72.70
# 8840         서울특별시       송파구           가락동          가락 현대     82.16
# 8841         서울특별시       송파구           가락동          가락 현대     84.46
# 8845         서울특별시       송파구           가락동          헬리오시티     49.29
# 8848         서울특별시       송파구           가락동          헬리오시티     59.96
# 8853         서울특별시       송파구           가락동       가락 쌍용 2차     59.88
# ...

# %%
price_time02['time_div'].value_counts()
# Out:
# 35분 ~ 40분    22
# 30분 ~ 35분     4
# 40분 ~ 45분     2
# Name: time_div, dtype: int64

# %%
price_time02.plot(x='price_per_size', y = 'time_div', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='price_per_size', ylabel='time_div'>
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
price_time03 = price_time_01[(price_time_01['gross_area_sub'] == '소형(공급20평대)')& (price_time_01['city_name'] == '송파구')]
ax = price_time03.plot(x='kb_price', y = 'time_div', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis = 'y',color='white')
ax.set_xlim(50000, 300000)
# Out:
# (50000.0, 300000.0)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ax = price_time02.plot(x='kb_price', y = 'time_div', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis = 'x',color='white')
ax.tick_params(axis = 'y',color='white')
# Out:
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '양천구')]
ax = price_time_01_1.plot(x='rent_per_size', y = 'time_div', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '중구')]

price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='price_per_size', y = 'time_div', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='price_per_size', y = 'pct_div', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/1412217676.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/1412217676.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

# %%
price_time_01_1['gross_area_sub'].value_counts()
# Out:
# 소형(공급20평대)       23
# 중형(공급30평대)       23
# 중대형(공급40평대)      11
# 초소형(공급 20평미만)     4
# 대형(공급50평대 이상)     4
# Name: gross_area_sub, dtype: int64

# %%
price_time_01_1 = price_time_01[(price_time_01['gross_area_sub'] == '소형(공급20평대)') & (price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='kb_rent', y = 'district_name', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전세가")
ax.set_ylabel("법정동")
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/4101017784.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/4101017784.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

# %%
price_time_01_1 = price_time_01[(price_time_01['net_area'] > 50 ) & (price_time_01['net_area'] < 60 ) & (price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='kb_rent', y = 'district_name', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전세가")
ax.set_ylabel("법정동")
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/2883514490.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/2883514490.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

# %%
price_time_01_1[price_time_01_1['gross_area_sub'] == '소형(공급20평대)']['kb_rent'].describe()
# Out:
# count       23.000000
# mean     59565.217391
# std      16017.252309
# min      28000.000000
# 25%      52000.000000
# 50%      63500.000000
# 75%      70500.000000
# max      83000.000000
# Name: kb_rent, dtype: float64

# %%
price_time_01_1 = price_time_01[(price_time_01['kb_rent'] < 50000) & (price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='net_area', y = 'district_name', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전용면적")
ax.set_ylabel("법정동")
# ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/155717644.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/155717644.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)
# Text(0, 0.5, '법정동')

# %%
price_time_01_1 = price_time_01[(price_time_01['kb_rent'] < 50000) & (price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='gross_area_sub', y = 'district_name', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전용면적")
ax.set_ylabel("법정동")
# ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/735226927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/735226927.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)
# Text(0, 0.5, '법정동')

# %%
price_time_01_1 = price_time_01[(price_time_01['gross_area_sub'] == '소형(공급20평대)') &  (price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='kb_rent', y = 'pct_div', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전세가")
ax.set_ylabel("(강남역)소요시간")
# ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/1651390129.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/1651390129.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)
# Text(0, 0.5, '(강남역)소요시간')

# %%
price_time_01_1 = price_time_01[(price_time_01['kb_rent'] <50000) &  (price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='net_area', y = 'pct_div', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전용면적")
ax.set_ylabel("(강남역)소요시간")
# ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/128481513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/128481513.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)
# Text(0, 0.5, '(강남역)소요시간')

# %%
price_time_01_1 = price_time_01[(price_time_01['kb_rent'] <50000) &  (price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='gross_area_sub', y = 'pct_div', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전용면적")
ax.set_ylabel("(강남역)소요시간")
# ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/3227626474.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/3227626474.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)
# Text(0, 0.5, '(강남역)소요시간')

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='kb_rent', y = 'net_area', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전세가")
ax.set_ylabel("전용면적")
# ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/3542797943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/3542797943.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)
# Text(0, 0.5, '전용면적')

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='kb_rent', y = 'gross_area_sub', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전세가")
ax.set_ylabel("면적")
# ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/1001383784.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/1001383784.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)
# Text(0, 0.5, '면적')

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='net_area', y = 'pct_div', kind = 'scatter')
ax.xaxis.label.set_color('black')
ax.yaxis.label.set_color('black')
ax.set_xlabel("전용면적")
ax.set_ylabel("(강남역)소요시간")
# ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/4140736823.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/4140736823.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)
# Text(0, 0.5, '(강남역)소요시간')

# %%
price_time_01_1['district_name'].value_counts()
# Out:
# 신당동      44
# 만리동2가     7
# 중림동       6
# 회현동1가     3
# 묵정동       3
# 만리동1가     2
# Name: district_name, dtype: int64

# %%
price_time_01_2 = price_time_01[(price_time_01['city_name'] == '강남구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_2['rank'] = price_time_01_2['강남역_소요시간'].rank(pct=True) * 100
price_time_01_2['pct_div'] = price_time_01_2.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_2.plot(x='kb_rent', y = 'district_name', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.set_xlabel("Time")
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)
# Out:
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/2787816796.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_2['rank'] = price_time_01_2['강남역_소요시간'].rank(pct=True) * 100
# C:\Users\jhpark\AppData\Local\Temp/ipykernel_24708/2787816796.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_time_01_2['pct_div'] = price_time_01_2.apply(lambda x : pct_div(x['rank']), axis = 1)

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '중구') & (price_time_01['province_name'] == '서울특별시')]
price_time_01_1['rank'] = price_time_01_1['강남역_소요시간'].rank(pct=True) * 100
price_time_01_1['pct_div'] = price_time_01_1.apply(lambda x : pct_div(x['rank']), axis = 1)

ax = price_time_01_1.plot(x='kb_rent', y = 'pct_div', kind = 'scatter')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.set_xlabel("Time")
ax.tick_params(axis = 'y',color='white')
# ax.set_xlim(50000, 300000)

# %%
sns.set_style("whitegrid")
sns.boxplot(x='pct_div', y = 'price_per_size', data = price_time_01_1)
# Out:
# <AxesSubplot:xlabel='pct_div', ylabel='price_per_size'>

# %%
price_time_01_1['pct_div'].value_counts()
# Out:
# 40    18
# 46    13
# 56    13
# 43    11
# 36    10
# Name: pct_div, dtype: int64

# %%
price_time_01_1 = price_time_01[(price_time_01['city_name'] == '중구')]

price_time_01_1.boxplot(by='time_div', column = ['price_per_size'], grid = False)
# Out:
# <AxesSubplot:title={'center':'price_per_size'}, xlabel='time_div'>
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set_style("whitegrid")
sns.boxplot(x='time_div', y = 'price_per_size', data = price_time_01_1)
# Out:
# <AxesSubplot:xlabel='time_div', ylabel='price_per_size'>
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jhpark\.conda\envs\snu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
final_result_addr_all.drop(columns=['kb_apartment_id', 'kb_unit_type_id']).corr()["price_per_size"].sort_values(ascending = False)
# Out:
# price_per_size            1.000000
# rent_per_size             0.823577
# 빌딩_5000                   0.679693
# 골프_2000                   0.575008
# 와인_2000                   0.560239
# IC_5000                   0.551526
# 헬스_2000                   0.543159
# 스타벅스_1000                 0.533100
# mart                      0.452850
# 병원_1000                   0.432588
# department_store          0.410783
# hospital                  0.409484
# culture                   0.359985
# number_of_parking         0.343959
# floor_highest_dong        0.341157
# 전기자동차 충전소_3000            0.335392
# city_id                   0.310863
# number_of_units_total     0.307998
# academy                   0.297808
# number_of_dongs           0.294487
# district_id               0.292195
# subway_index              0.291234
# subway                    0.286409
# harmful_facility          0.267017
# 상가_200                    0.229839
# 도시근린공원_2000               0.222109
# kb_rent_growth_36         0.207397
# ...

# %%
final_result_addr_all.drop(columns=['kb_apartment_id', 'kb_unit_type_id']).corr()["rent_per_size"].sort_values(ascending = False)
# Out:
# rent_per_size             1.000000
# price_per_size            0.823577
# 빌딩_5000                   0.593947
# 골프_2000                   0.526553
# 헬스_2000                   0.512272
# floor_highest_dong        0.507500
# 스타벅스_1000                 0.493792
# 와인_2000                   0.487966
# IC_5000                   0.473542
# mart                      0.391103
# 병원_1000                   0.376232
# department_store          0.373867
# hospital                  0.347838
# culture                   0.344362
# number_of_parking         0.320067
# academy                   0.300192
# 전기자동차 충전소_3000            0.287932
# harmful_facility          0.282731
# kb_rent_growth_36         0.276217
# city_id                   0.256751
# subway_index              0.250200
# subway                    0.247951
# district_id               0.240394
# number_of_units_total     0.230485
# number_of_dongs           0.230250
# floor_lowest_dong         0.229264
# 카셰어링_1000                 0.226081
# ...
